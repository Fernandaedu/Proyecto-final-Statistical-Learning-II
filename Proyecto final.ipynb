# %% [markdown]
# # Proyecto Final
#
# #  ANN y RNN

# %% [markdown]
# Tesla, Inc. diseña, desarrolla, fabrica, alquila y vende vehículos eléctricos y sistemas de generación y almacenamiento de energía en los Estados Unidos, China e internacionalmente. La empresa opera en dos segmentos, Automoción y almacenamiento de energía. Sus productos principales en el mercado son automóviles eléctricos, baterías para almacenamiento de energía, paneles solares y tejas solares. La información utilizada contiene los datos históricos sobre las acciones de la compañia, los cuales estan registrados en Dólares Americanos y registros diarios.
#
# El dataset esta compuestos de 7 columnas, con 2956 registros
# -   Date: Fecha de la transacción
# -	Open: Precio de la primera transacción del día
# -	High: precio más alto del día
# -	Low: Precio más bajo de día
# -	Close: Precio de la última transacción del día
# -	Adj Close: Precio de cierre ajustado para reflejar el valor después de contabilidar cualquier acción
# -	Volume: Número de unidades negociadas en el día
#
# Con los datos proporcionado se realizará la predicción de un modelo de regresión de los precios de las acciones, con base a los registros historicos de los precios diario de acciones, contiene datos a partir del 28 de junio de 2010 al 22 de marzo de 2022. Exploraremos el conjunto de datos para realizar el análisis y comprender el comportamiento histórico de las acciones de Tesla en el mercado de valores..

# %%
import numpy as np 
import pandas as pd
import os
import plotly.graph_objects as go
from keras.models import Sequential
import keras
from summarytools  import dfSummary

# %%
# En el siguiente código importaremos nuestro dataset que está en formato csv

dataset = pd.read_csv('TSLA.csv')
dataset.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2010-06-29  3.800  5.000  3.508  4.778      4.778  93831500
# 1  2010-06-30  5.158  6.084  4.660  4.766      4.766  85935500
# 2  2010-07-01  5.000  5.184  4.054  4.392      4.392  41094000
# 3  2010-07-02  4.600  4.620  3.742  3.840      3.840  25699000
# 4  2010-07-06  4.000  4.000  3.166  3.222      3.222  34334500

# %% [markdown]
# ### A continuación haremos una ingeniería de características, el primer paso aseguarar que los campos no tengan registros nulos y si tienen no soprepasen el 5 % de lo contrario se eliminan

# %%
cols_rescatables = [col for col in dataset.columns if (dataset[col].isnull().mean() <= 0.05)]
cols_rescatables
# Out:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']

# %%
dataset1 = dataset[cols_rescatables].dropna()
dataset.shape, dataset1.shape
# Out:
# ((2956, 7), (2956, 7))

# %% [markdown]
# ### Se verificó que la data está integra ya que no se identificó campos con registros nulos, debido a que se obtuvo el mismo resultado, por ende se utilizará la data original

# %% [markdown]
# ### El siguiente script proporcionará un resumen de las variables que tiene el dataset

# %%
dfSummary(dataset)
# Out:
# <style type="text/css">
# #T_ff375 thead>tr>th {
#   text-align: left;
# }
# #T_ff375_row0_col0, #T_ff375_row1_col0, #T_ff375_row2_col0, #T_ff375_row3_col0, #T_ff375_row4_col0, #T_ff375_row5_col0, #T_ff375_row6_col0 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 5%;
#   max-width: 50px;
#   min-width: 20px;
# }
# #T_ff375_row0_col1, #T_ff375_row1_col1, #T_ff375_row2_col1, #T_ff375_row3_col1, #T_ff375_row4_col1, #T_ff375_row5_col1, #T_ff375_row6_col1 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 15%;
#   max-width: 200px;
#   min-width: 100px;
#   word-break: break-word;
# }
# #T_ff375_row0_col2, #T_ff375_row1_col2, #T_ff375_row2_col2, #T_ff375_row3_col2, #T_ff375_row4_col2, #T_ff375_row5_col2, #T_ff375_row6_col2 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 30%;
#   min-width: 100px;
# }
# #T_ff375_row0_col3, #T_ff375_row1_col3, #T_ff375_row2_col3, #T_ff375_row3_col3, #T_ff375_row4_col3, #T_ff375_row5_col3, #T_ff375_row6_col3 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 25%;
#   min-width: 100px;
# }
# #T_ff375_row0_col4, #T_ff375_row1_col4, #T_ff375_row2_col4, #T_ff375_row3_col4, #T_ff375_row4_col4, #T_ff375_row5_col4, #T_ff375_row6_col4 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 20%;
#   min-width: 150px;
# }
# #T_ff375_row0_col5, #T_ff375_row1_col5, #T_ff375_row2_col5, #T_ff375_row3_col5, #T_ff375_row4_col5, #T_ff375_row5_col5, #T_ff375_row6_col5 {
#   text-align: left;
#   font-size: 12px;
#   vertical-align: middle;
#   width: 10%;
# }
# </style>
# <table id="T_ff375">
#   <caption><strong>Data Frame Summary</strong><br>dataset<br>Dimensions: 2,956 x 7<br>Duplicates: 0</caption>
#   <thead>
#     <tr>
#       <th id="T_ff375_level0_col0" class="col_heading level0 col0" >No</th>
#       <th id="T_ff375_level0_col1" class="col_heading level0 col1" >Variable</th>
#       <th id="T_ff375_level0_col2" class="col_heading level0 col2" >Stats / Values</th>
#       <th id="T_ff375_level0_col3" class="col_heading level0 col3" >Freqs / (% of Valid)</th>
#       <th id="T_ff375_level0_col4" class="col_heading level0 col4" >Graph</th>
#       <th id="T_ff375_level0_col5" class="col_heading level0 col5" >Missing</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ff375_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_ff375_row0_col1" class="data row0 col1" ><strong>Date</strong><br>[object]</td>
#       <td id="T_ff375_row0_col2" class="data row0 col2" >1. 2010-06-29<br>2. 2018-05-02<br>3. 2018-04-19<br>4. 2018-04-20<br>5. 2018-04-23<br>6. 2018-04-24<br>7. 2018-04-25<br>8. 2018-04-26<br>9. 2018-04-27<br>10. 2018-04-30<br>11. other</td>
#       <td id="T_ff375_row0_col3" class="data row0 col3" >1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>1 (0.0%)<br>2,946 (99.7%)</td>
#       <td id="T_ff375_row0_col4" class="data row0 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row0_col5" class="data row0 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_ff375_row1_col1" class="data row1 col1" ><strong>Open</strong><br>[float64]</td>
#       <td id="T_ff375_row1_col2" class="data row1 col2" >Mean (sd) : 138.7 (250.0)<br>min < med < max:<br>3.2 < 46.7 < 1234.4<br>IQR (CV) : 48.4 (0.6)</td>
#       <td id="T_ff375_row1_col3" class="data row1 col3" >2,666 distinct values</td>
#       <td id="T_ff375_row1_col4" class="data row1 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row1_col5" class="data row1 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_ff375_row2_col1" class="data row2 col1" ><strong>High</strong><br>[float64]</td>
#       <td id="T_ff375_row2_col2" class="data row2 col2" >Mean (sd) : 141.8 (255.9)<br>min < med < max:<br>3.3 < 47.5 < 1243.5<br>IQR (CV) : 49.0 (0.6)</td>
#       <td id="T_ff375_row2_col3" class="data row2 col3" >2,662 distinct values</td>
#       <td id="T_ff375_row2_col4" class="data row2 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row2_col5" class="data row2 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_ff375_row3_col1" class="data row3 col1" ><strong>Low</strong><br>[float64]</td>
#       <td id="T_ff375_row3_col2" class="data row3 col2" >Mean (sd) : 135.4 (243.8)<br>min < med < max:<br>3.0 < 45.8 < 1217.0<br>IQR (CV) : 47.8 (0.6)</td>
#       <td id="T_ff375_row3_col3" class="data row3 col3" >2,672 distinct values</td>
#       <td id="T_ff375_row3_col4" class="data row3 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row3_col5" class="data row3 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ff375_row4_col1" class="data row4 col1" ><strong>Close</strong><br>[float64]</td>
#       <td id="T_ff375_row4_col2" class="data row4 col2" >Mean (sd) : 138.8 (250.1)<br>min < med < max:<br>3.2 < 46.5 < 1229.9<br>IQR (CV) : 48.5 (0.6)</td>
#       <td id="T_ff375_row4_col3" class="data row4 col3" >2,764 distinct values</td>
#       <td id="T_ff375_row4_col4" class="data row4 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row4_col5" class="data row4 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row5_col0" class="data row5 col0" >6</td>
#       <td id="T_ff375_row5_col1" class="data row5 col1" ><strong>Adj Close</strong><br>[float64]</td>
#       <td id="T_ff375_row5_col2" class="data row5 col2" >Mean (sd) : 138.8 (250.1)<br>min < med < max:<br>3.2 < 46.5 < 1229.9<br>IQR (CV) : 48.5 (0.6)</td>
#       <td id="T_ff375_row5_col3" class="data row5 col3" >2,764 distinct values</td>
#       <td id="T_ff375_row5_col4" class="data row5 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row5_col5" class="data row5 col5" >0<br>(0.0%)</td>
#     </tr>
#     <tr>
#       <td id="T_ff375_row6_col0" class="data row6 col0" >7</td>
#       <td id="T_ff375_row6_col1" class="data row6 col1" ><strong>Volume</strong><br>[int64]</td>
#       <td id="T_ff375_row6_col2" class="data row6 col2" >Mean (sd) : 31314485.7 (27983828.8)<br>min < med < max:<br>592500.0 < 24886800.0 < 304694000.0<br>IQR (CV) : 26635875.0 (1.1)</td>
#       <td id="T_ff375_row6_col3" class="data row6 col3" >2,925 distinct values</td>
#       <td id="T_ff375_row6_col4" class="data row6 col4" ><img src = "......"></img></td>
#       <td id="T_ff375_row6_col5" class="data row6 col5" >0<br>(0.0%)</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Del resumen anterior se identificó que la variable con mayor promedio es el volumen de los precios de los vehiculos donde ocurrió en el 2018

# %%
dataset.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2956.000000  2956.000000  2956.000000  2956.000000  2956.000000
# mean    138.691296   141.771603   135.425953   138.762183   138.762183
# std     250.044839   255.863239   243.774157   250.123115   250.123115
# min       3.228000     3.326000     2.996000     3.160000     3.160000
# 25%      19.627000    20.402000    19.127500    19.615000    19.615000
# 50%      46.656999    47.487001    45.820002    46.545000    46.545000
# 75%      68.057001    69.357500    66.911501    68.103998    68.103998
# max    1234.410034  1243.489990  1217.000000  1229.910034  1229.910034
#
#              Volume
# count  2.956000e+03
# mean   3.131449e+07
# std    2.798383e+07
# min    5.925000e+05
# 25%    1.310288e+07
# 50%    2.488680e+07
# 75%    3.973875e+07
# max    3.046940e+08

# %% [markdown]
# # Verificación de valores nulos

# %%
dataset.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import seaborn as sns

# %% [markdown]
# No se encontró valores nulos en el dataset

# %% [markdown]
# ### A continuación se mostrará el comportamiento de los precios a través de un grafico de velas (candlestick chart en inglés) muestra la información de precios en un período de tiempo específico de una manera visualmente comprensible

# %%
start_index = 500
end_index = None  
selected_data = dataset.iloc[start_index:end_index]

fig = go.Figure(data=[go.Candlestick(x=selected_data['Date'],
                open=selected_data['Open'],
                high=selected_data['High'],
                low=selected_data['Low'],
                close=selected_data['Adj Close'])])

fig.update_layout(
    title='Gráfico de velas',
    xaxis_title='Fecha',
    yaxis_title='Precio',
)

# Muestra el gráfico
fig.show()

# %% [markdown]
# ### En la siguiente línea de código nos aseguraremos que la variable que se utilizará para predecir (Adj Close), esté en el formato correcto

# %%
dataset['Adj Close'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Verificación del tipo de datos del precio

# %% [markdown]
# ### La Prueba de Dickey-Fuller Aumentada (ADF) es una herramienta estadística para analizar la serie de tiempo de los precios de los vehiculos e identificar, si exhibe una tendencia estocástica o no estacionaria

# %%
from statsmodels.tsa.stattools import adfuller

# prueba ADF
adf_result = adfuller(dataset['Adj Close'].values, autolag='AIC')

# resultados de la prueba
print("Prueba de Dickey-Fuller Aumentada (ADF)")
print("---------------------------------------")
print(f"Estadística ADF: {adf_result[0]}")
print(f"Valor p: {adf_result[1]}")
print("Valores críticos:")
for key, value in adf_result[4].items():
    print(f"   {key}: {value}")

# Interpretación de los resultados
print("---------------------------------------")
if adf_result[1] <= 0.05:
    print("Conclusion: El valor p es menor o igual a 0.05, por lo que rechazamos la hipótesis nula.")
    print("La serie temporal es estacionaria.")
else:
    print("Conclusion: El valor p es mayor a 0.05, por lo que no podemos rechazar la hipótesis nula.")
    print("La serie temporal no es estacionaria.")
# Out:
# Prueba de Dickey-Fuller Aumentada (ADF)
# ---------------------------------------
# Estadística ADF: 1.4239415939225966
# Valor p: 0.9972202364261444
# Valores críticos:
#    1%: -3.4325860929804404
#    5%: -2.8625279573644873
#    10%: -2.5672959172141048
# ---------------------------------------
# Conclusion: El valor p es mayor a 0.05, por lo que no podemos rechazar la hipótesis nula.
# La serie temporal no es estacionaria.

# %% [markdown]
# # Función de autocorrelación

# %% [markdown]
# ### A continuación se desarrollará las funciones de autocorrelación  para identificar los patrones en una serie de tiempo para ver si existe una autocorrelación con los datos anteriores

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

def plot_acf_pacf(data, lags=None):
   
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

    # Gráfico ACF
    plot_acf(data, lags=lags, ax=ax1)
    ax1.set_title('Autocorrelation Function (ACF)')

    # Gráfico PACF
    plot_pacf(data, lags=lags, ax=ax2)
    ax2.set_title('Partial Autocorrelation Function (PACF)')

    plt.show()

# conjunto de datos con un nombre más descriptivo
df = dataset['Adj Close']

# Muestra los gráficos ACF y PACF
plot_acf_pacf(df, lags=20)

# %% [markdown]
# ### En el grafico anterior se pudo  analisar mejor los precios de cierre de las acciones de los vehiculos en el grafico de de ACF ya que se aprecia el procentaje no sobrepasa en 25 %

# %% [markdown]
# ## Construcción de los modelos de red neuronal ANN Y RNN

# %% [markdown]
# # ANN - Artificial Neural Network

# %% [markdown]
# ### Primero se evaluará la variable que nos servirá para el modelo de la serie de tiempo el cual es: Adj Close

# %%
data = dataset['Adj Close'].values
print('Shape of data: ', data.shape)
# Out:
# Shape of data:  (2956,)

# %% [markdown]
# ### se construirá el modelo en donde utilizaremos el 80 % de entrenamiento y el resto (20 %) se utilizará para la prueba

# %%
# longitud de entrenamiento como el 80% de los datos
train_length = int(len(data) * 0.8)

# Datos en conjuntos de entrenamiento y prueba
train_data, test_data = data[:train_length], data[train_length:]

# Imprime la longitud del conjunto de entrenamiento
print('Train length:', train_length)

# Imprime las formas de los conjuntos de entrenamiento y prueba
print('Shape of Train data:', train_data.shape)
print('Shape of Test data:', test_data.shape)
# Out:
# Train length: 2364
# Shape of Train data: (2364,)
# Shape of Test data: (592,)

# %% [markdown]
# ### A continuación se reaorganizará la estructura de datos utilizando el np.reshape de numpy

# %%
train_data = np.reshape(train_data, (-1, 1))
test_data = np.reshape(test_data, (-1, 1))

# Imprime las formas de los conjuntos de entrenamiento y prueba
print(f'Shape of Train data: {train_data.shape}')
print(f'Shape of Test data: {test_data.shape}')
# Out:
# Shape of Train data: (2364, 1)
# Shape of Test data: (592, 1)

# %% [markdown]
# ### A continuación se creará una una función del conjunto de datos para analizar la serie de tiempo que servirá para ver la autocorrelación

# %%
def create_dataset(dataset, lookback):
    dataX, dataY = [], []
    for i in range(len(dataset) - lookback -1):
        a = dataset[i: (i+lookback), 0]
        dataX.append(a)
        b = dataset[i+lookback, 0]
        dataY.append(b)
    return np.array(dataX), np.array(dataY)

# %%
plot_pacf(data, lags=10)
plt.show()

# %% [markdown]
# ### A continuación importaremos la librería "pacf", ésta es una herramienta estadística que se utiliza en el análisis de series temporales para entender la correlación entre los valores de una serie en diferentes rezagos, controlando o eliminando el efecto de los rezagos intermedios.

# %%
from statsmodels.tsa.stattools import pacf

# %% [markdown]
# ### Utilizando la siguiente función pacf, utilizando 20 rezagos calcularemos cuantas regresiones son superiores al 10 %

# %%
pacf_value = pacf(data, nlags=20)
lag = 0

for x in pacf_value:
    if x > 0.1:
        lag += 1
    else:
        break
print('Selected look_back (or lag = ): ', lag)
# Out:
# Selected look_back (or lag = ):  2

# %%
train_X, train_y = create_dataset(train_data, lag)
test_X, test_y = create_dataset(test_data, lag)

# %% [markdown]
# ### Ya identifcado los rezagos, se le añadirá en el modelo tranto para la prueba como para el entrenamiento

# %%
print('Shape of train_X and train_y: ', train_X.shape, train_y.shape)
print('Shape of test_X and test_y: ', test_X.shape, test_y.shape)
# Out:
# Shape of train_X and train_y:  (2361, 2) (2361,)
# Shape of test_X and test_y:  (589, 2) (589,)

# %% [markdown]
# ### Se imprimirá como quedó el modelo, en donde se hace la comparativa de lo original con lo calculado por el modelo

# %%
print(train_data[:20])
for x in range(len(train_X[:20])):
    print(test_X[x], test_y[x], )
# Out:
# [[4.778]
#  [4.766]
#  [4.392]
#  [3.84 ]
#  [3.222]
#  [3.16 ]
#  [3.492]
#  [3.48 ]
#  [3.41 ]
#  [3.628]
#  [3.968]
#  [3.978]
#  [4.128]
#  [4.382]
#  [4.06 ]
#  [4.044]
#  [4.2  ]
#  [4.258]
#  [4.19 ]
#  [4.11 ]]
# [69.998001 71.903999] 70.444
# [71.903999 70.444   ] 70.966003
# [70.444    70.966003] 66.608002
# [70.966003 66.608002] 67.267998
# [66.608002 67.267998] 65.783997
# [67.267998 65.783997] 66.258003
# [65.783997 66.258003] 65.987999
# [66.258003 65.987999] 66.973999
# [65.987999 66.973999] 67.239998
# [66.973999 67.239998] 66.606003
# [67.239998 66.606003] 66.073997
# [66.606003 66.073997] 67.178001
# [66.073997 67.178001] 67.905998
# [67.178001 67.905998] 69.767998
# [67.905998 69.767998] 70.540001
# [69.767998 70.540001] 71.935997
# [70.540001 71.935997] 71.678001
# [71.935997 71.678001] 76.300003
# [71.678001 76.300003] 75.797997
# [76.300003 75.797997] 78.629997

# %% [markdown]
# ### Para inicar la estructura del modelo, se eligió 7 semillas para ver su comportamiento

# %%
np.random.seed(7)

# %% [markdown]
# ### Se importará las librerías de secuencia, desnidad y ativación de tensorflow para constuir las capas de la rede neuronal

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from keras.models import Sequential
import keras

# %% [markdown]
# ### El siguiente código servirá para construir la red nueronal, la cual estará conformada por 2 capas densas una con 64 neuronas la de entrada y una neurona la de salida, esta última se eligió con una neurona porque es un modelo de regresión, si hubiera sido uno de claisficación con múltiples opciones, se agregaría más neuronas

# %%
# Creando un modelo secuencial
model = Sequential()

# Capa oculta 1
model.add(Dense(64, input_dim=lag, activation='relu', name='1st_hidden'))

# Capa de salida
model.add(Dense(1, name='Output_layer', activation='linear'))

# Compilar el modelo
model.compile(loss='mean_squared_error', optimizer='adam')

# Resumen del modelo
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  1st_hidden (Dense)          (None, 64)                192
#
#  Output_layer (Dense)        (None, 1)                 65
#
# =================================================================
# Total params: 257 (1.00 KB)
# Trainable params: 257 (1.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### A continuación, ponemos en ejecución la red nueuronal, utilizando 100 épocas y 64 batches de los daos validando con el 0.1

# %%
epoch_number = 100
batches = 64

history = model.fit(train_X, train_y, epochs = epoch_number, batch_size = batches, verbose = 1, shuffle=False, 
                    validation_split=0.1)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 2s 11ms/step - loss: 791.6970 - val_loss: 696.0339
# Epoch 2/100
# 34/34 [==============================] - 0s 3ms/step - loss: 107.4808 - val_loss: 60.1782
# Epoch 3/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.7820 - val_loss: 5.3433
# Epoch 4/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.2685 - val_loss: 5.2701
# Epoch 5/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.1204 - val_loss: 5.2109
# Epoch 6/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.1104 - val_loss: 5.2035
# Epoch 7/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.1030 - val_loss: 5.1869
# Epoch 8/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0972 - val_loss: 5.1716
# Epoch 9/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0902 - val_loss: 5.1552
# Epoch 10/100
# 34/34 [==============================] - 0s 4ms/step - loss: 2.0834 - val_loss: 5.1382
# Epoch 11/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0762 - val_loss: 5.1208
# Epoch 12/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0688 - val_loss: 5.1029
# Epoch 13/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0612 - val_loss: 5.0846
# Epoch 14/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0535 - val_loss: 5.0660
# Epoch 15/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0457 - val_loss: 5.0472
# Epoch 16/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0378 - val_loss: 5.0280
# Epoch 17/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0298 - val_loss: 5.0087
# Epoch 18/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0217 - val_loss: 4.9892
# Epoch 19/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0136 - val_loss: 4.9696
# Epoch 20/100
# 34/34 [==============================] - 0s 3ms/step - loss: 2.0055 - val_loss: 4.9499
# Epoch 21/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9973 - val_loss: 4.9301
# Epoch 22/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9891 - val_loss: 4.9102
# Epoch 23/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9810 - val_loss: 4.8904
# Epoch 24/100
# 34/34 [==============================] - 0s 2ms/step - loss: 1.9728 - val_loss: 4.8705
# Epoch 25/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9646 - val_loss: 4.8506
# Epoch 26/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9564 - val_loss: 4.8307
# Epoch 27/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9483 - val_loss: 4.8108
# Epoch 28/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9402 - val_loss: 4.7909
# Epoch 29/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9321 - val_loss: 4.7710
# Epoch 30/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.9240 - val_loss: 4.7512
# Epoch 31/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.9160 - val_loss: 4.7314
# Epoch 32/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.9081 - val_loss: 4.7117
# Epoch 33/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.9002 - val_loss: 4.6920
# Epoch 34/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8923 - val_loss: 4.6724
# Epoch 35/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8846 - val_loss: 4.6529
# Epoch 36/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8769 - val_loss: 4.6335
# Epoch 37/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8693 - val_loss: 4.6141
# Epoch 38/100
# 34/34 [==============================] - 0s 7ms/step - loss: 1.8617 - val_loss: 4.5949
# Epoch 39/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8543 - val_loss: 4.5757
# Epoch 40/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8470 - val_loss: 4.5567
# Epoch 41/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8398 - val_loss: 4.5379
# Epoch 42/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.8328 - val_loss: 4.5192
# Epoch 43/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.8259 - val_loss: 4.5006
# Epoch 44/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8191 - val_loss: 4.4823
# Epoch 45/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8126 - val_loss: 4.4641
# Epoch 46/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8063 - val_loss: 4.4463
# Epoch 47/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.8002 - val_loss: 4.4287
# Epoch 48/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7943 - val_loss: 4.4114
# Epoch 49/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7888 - val_loss: 4.3945
# Epoch 50/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7836 - val_loss: 4.3781
# Epoch 51/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7787 - val_loss: 4.3621
# Epoch 52/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7743 - val_loss: 4.3467
# Epoch 53/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7702 - val_loss: 4.3321
# Epoch 54/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7666 - val_loss: 4.3183
# Epoch 55/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7634 - val_loss: 4.3054
# Epoch 56/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7606 - val_loss: 4.2934
# Epoch 57/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7582 - val_loss: 4.2825
# Epoch 58/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.7560 - val_loss: 4.2726
# Epoch 59/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7538 - val_loss: 4.2638
# Epoch 60/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7515 - val_loss: 4.2558
# Epoch 61/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.7489 - val_loss: 4.2485
# Epoch 62/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7455 - val_loss: 4.2415
# Epoch 63/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7413 - val_loss: 4.2343
# Epoch 64/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7359 - val_loss: 4.2264
# Epoch 65/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7291 - val_loss: 4.2173
# Epoch 66/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.7209 - val_loss: 4.2064
# Epoch 67/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.7114 - val_loss: 4.1933
# Epoch 68/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.7007 - val_loss: 4.1778
# Epoch 69/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.6892 - val_loss: 4.1601
# Epoch 70/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.6772 - val_loss: 4.1403
# Epoch 71/100
# 34/34 [==============================] - 0s 9ms/step - loss: 1.6652 - val_loss: 4.1190
# Epoch 72/100
# 34/34 [==============================] - 0s 7ms/step - loss: 1.6535 - val_loss: 4.0966
# Epoch 73/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.6424 - val_loss: 4.0739
# Epoch 74/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.6320 - val_loss: 4.0513
# Epoch 75/100
# 34/34 [==============================] - 0s 11ms/step - loss: 1.6224 - val_loss: 4.0292
# Epoch 76/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.6137 - val_loss: 4.0077
# Epoch 77/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.6055 - val_loss: 3.9871
# Epoch 78/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.5980 - val_loss: 3.9672
# Epoch 79/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5909 - val_loss: 3.9480
# Epoch 80/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5842 - val_loss: 3.9295
# Epoch 81/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5778 - val_loss: 3.9114
# Epoch 82/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5716 - val_loss: 3.8938
# Epoch 83/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.5656 - val_loss: 3.8766
# Epoch 84/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.5598 - val_loss: 3.8597
# Epoch 85/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.5542 - val_loss: 3.8432
# Epoch 86/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.5486 - val_loss: 3.8270
# Epoch 87/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.5433 - val_loss: 3.8111
# Epoch 88/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.5380 - val_loss: 3.7955
# Epoch 89/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.5328 - val_loss: 3.7802
# Epoch 90/100
# 34/34 [==============================] - 0s 6ms/step - loss: 1.5278 - val_loss: 3.7651
# Epoch 91/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.5228 - val_loss: 3.7504
# Epoch 92/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.5180 - val_loss: 3.7358
# Epoch 93/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.5132 - val_loss: 3.7216
# Epoch 94/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.5086 - val_loss: 3.7076
# Epoch 95/100
# 34/34 [==============================] - 0s 3ms/step - loss: 1.5040 - val_loss: 3.6939
# Epoch 96/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.4996 - val_loss: 3.6804
# Epoch 97/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.4952 - val_loss: 3.6672
# Epoch 98/100
# 34/34 [==============================] - 0s 8ms/step - loss: 1.4910 - val_loss: 3.6543
# Epoch 99/100
# 34/34 [==============================] - 0s 4ms/step - loss: 1.4869 - val_loss: 3.6416
# Epoch 100/100
# 34/34 [==============================] - 0s 5ms/step - loss: 1.4828 - val_loss: 3.6292

# %% [markdown]
# ### A continuación se realizará el comparativo de la estructura de la red neuronal de las epocas de marge de perdida entre el modelo de entrenamiento y el de prueba

# %%
plt.clf()

# Tamaño de la figura
plt.figure(figsize=(10, 8))

# Datos de entrenamiento y prueba
train_loss = history.history['loss']
test_loss = history.history['val_loss']

# Gráfico de entrenamiento y prueba
plt.plot(train_loss, label='Train Loss')
plt.plot(test_loss, label='Test Loss')

# Etiquetas y título
plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Training and Testing Loss over Epochs')

# Leyenda con nombres de series
plt.legend()

# Gráfico
plt.show()

# %% [markdown]
# ### En el resultado del gráfico anterior se constató que en las primeras 3 epocas se vio la diferencia de peridad por lo que no era necesario utilizar más de lo indicado

# %%
# Realizar predicciones en el conjunto de prueba
test_predictions = model.predict(test_X)
# Out:
# 19/19 [==============================] - 0s 2ms/step

# %%
test_predictions[:15]
# Out:
# array([[71.33387 ],
#        [70.88867 ],
#        [70.813385],
#        [67.928345],
#        [67.07662 ],
#        [66.23943 ],
#        [66.123405],
#        [66.077675],
#        [66.68467 ],
#        [67.167305],
#        [66.80483 ],
#        [66.24251 ],
#        [66.85299 ],
#        [67.69366 ],
#        [69.21273 ]], dtype=float32)

# %% [markdown]
# ### Con el siguiente código, obtendremos el punteo de la prueba de la red neuronal

# %%
import math
from sklearn.metrics import mean_squared_error

testScore = math.sqrt(mean_squared_error(test_y[:], test_predictions[:,0]))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Test Score: 26.00 RMSE

# %% [markdown]
# ### A continaución se mostrará de forma gráfica la comparativa de predicción vs los datos reales del modelo, para verificar el resultado si es optimo o no

# %%
# Crear una figura
plt.figure(figsize=(16, 8))
plt.rcParams.update({'font.size': 12})

# Trazar los datos reales en azul
plt.plot(test_y[:], color='blue', label='Actual')

# Trazar las predicciones en naranja
plt.plot(test_predictions[:, 0], color='orange', label='Predicted')

# Título del gráfico
plt.title('Previsión del precio de las acciones de Tesla ')
plt.xlabel('Tiempo [en días]')
plt.ylabel('Precio de las acciones de Tesla [in Dollar]')

# Leyenda con etiquetas claras
plt.legend(['Actual', 'Predicted'])

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # RNN - Recurrent Neural Network

# %%
data = dataset['Adj Close'].values
print('Shape of data: ', data.shape)
# Out:
# Shape of data:  (2956,)

# %% [markdown]
# ### En el siguiente script se dividrá el conjunto de datos entre el de prueba con el del entrenamiento, el cual éste último será del 80 %

# %%
# Calcula la longitud del conjunto de entrenamiento como el 80% de los datos
train_length = int(len(data) * 0.8)

# Imprime la longitud del conjunto de entrenamiento
print('Train length:', train_length)

# Divide los datos en conjuntos de entrenamiento y prueba
train_data, test_data = data[:train_length], data[train_length:]

# Imprime las formas (longitud) de los conjuntos de entrenamiento y prueba
print('Shape of Train data:', train_data.shape)
print('Shape of Test data:', test_data.shape)
# Out:
# Train length: 2364
# Shape of Train data: (2364,)
# Shape of Test data: (592,)

# %% [markdown]
# ### Se crea una función para ver la secuencia de los ejes

# %%
from numpy import array
def split_sequence(sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        end_ix = i + n_steps
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
lag = 2 
n_features = 1

# %%
train_X, train_y = split_sequence(train_data, lag)
test_X, test_y = split_sequence(test_data, lag)

# %%
print(f'Shape of train_X: {train_X.shape}, train_y: {train_y.shape}')
print(f'Shape of test_X: {test_X.shape}, test_y: {test_y.shape}')
# Out:
# Shape of train_X: (2362, 2), train_y: (2362,)
# Shape of test_X: (590, 2), test_y: (590,)

# %%
train_X = train_X.reshape((train_X.shape[0], train_X.shape[1], n_features))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[1], n_features))

# %% [markdown]
# ### se imprimirá los valores del modelo de entrenamiento el cual está conformado por 2 lag y una característica

# %%
print('Shape of train_X and train_y: ', train_X.shape, train_y.shape)
print('Shape of test_X and test_y: ', test_X.shape, test_y.shape)
# Out:
# Shape of train_X and train_y:  (2362, 2, 1) (2362,)
# Shape of test_X and test_y:  (590, 2, 1) (590,)

# %%
# Se importará las librerías de densidad, secuencia, simplicidad y el LSTM

from keras.models import Sequential
from keras.layers import SimpleRNN
from keras.layers import Dense

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

# Definir el modelo Sequential
model = Sequential()

# Capa SimpleRNN con 64 unidades y función de activación ReLU
model.add(SimpleRNN(64, activation='relu', return_sequences=False, input_shape=(lag, n_features)))

# Capa de salida con una función de activación lineal para regresión
model.add(Dense(1, activation='linear'))

# Compilar el modelo con el optimizador 'adam' y la pérdida 'mse' (error cuadrático medio)
model.compile(optimizer='adam', loss='mse')

# Resumen del modelo
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 64)                4224
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 4289 (16.75 KB)
# Trainable params: 4289 (16.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
import tensorflow as tf
tf.config.run_functions_eagerly(True)

# %%
# Entrenar el modelo
history = model.fit(
    x=train_X,  
    y=train_y,  
    epochs=50,  
    batch_size=64,  
    verbose=1,  
    validation_split=0.1  
)
# Out:
# c:\Users\David\AppData\Local\Programs\Python\Python311\Lib\site-packages\tensorflow\python\data\ops\structured_function.py:265: UserWarning:
#
# Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
# Epoch 1/50
#  6/34 [====>.........................] - ETA: 3s - loss: 1795.6398
# 34/34 [==============================] - 3s 93ms/step - loss: 784.1750 - val_loss: 57.9757
# Epoch 2/50
# 34/34 [==============================] - 2s 73ms/step - loss: 8.7115 - val_loss: 6.2190
# Epoch 3/50
# 34/34 [==============================] - 2s 58ms/step - loss: 2.1366 - val_loss: 4.9220
# Epoch 4/50
# 34/34 [==============================] - 2s 62ms/step - loss: 1.9750 - val_loss: 4.9193
# Epoch 5/50
# 34/34 [==============================] - 2s 54ms/step - loss: 1.9681 - val_loss: 4.9370
# Epoch 6/50
# 34/34 [==============================] - 2s 64ms/step - loss: 1.9866 - val_loss: 4.9168
# Epoch 7/50
# 34/34 [==============================] - 3s 84ms/step - loss: 1.9647 - val_loss: 4.9106
# Epoch 8/50
# 34/34 [==============================] - 2s 64ms/step - loss: 1.9638 - val_loss: 4.9927
# Epoch 9/50
# 34/34 [==============================] - 3s 74ms/step - loss: 1.9730 - val_loss: 4.9137
# Epoch 10/50
# 34/34 [==============================] - 1s 41ms/step - loss: 1.9701 - val_loss: 4.8982
# Epoch 11/50
# 34/34 [==============================] - 2s 45ms/step - loss: 2.0106 - val_loss: 4.9198
# Epoch 12/50
# 34/34 [==============================] - 1s 41ms/step - loss: 1.9634 - val_loss: 4.8896
# Epoch 13/50
# 34/34 [==============================] - 2s 55ms/step - loss: 1.9618 - val_loss: 4.8856
# Epoch 14/50
# 34/34 [==============================] - 1s 39ms/step - loss: 1.9543 - val_loss: 4.8894
# Epoch 15/50
# 34/34 [==============================] - 2s 45ms/step - loss: 1.9614 - val_loss: 4.8752
# Epoch 16/50
# 34/34 [==============================] - 2s 42ms/step - loss: 1.9502 - val_loss: 4.8901
# Epoch 17/50
# 34/34 [==============================] - 1s 40ms/step - loss: 1.9366 - val_loss: 5.0591
# Epoch 18/50
# 34/34 [==============================] - 1s 39ms/step - loss: 1.9966 - val_loss: 4.9479
# Epoch 19/50
# 34/34 [==============================] - 1s 37ms/step - loss: 1.9643 - val_loss: 4.9130
# Epoch 20/50
# 34/34 [==============================] - 1s 41ms/step - loss: 1.9793 - val_loss: 4.8832
# Epoch 21/50
# 34/34 [==============================] - 2s 61ms/step - loss: 1.9388 - val_loss: 4.8463
# Epoch 22/50
# 34/34 [==============================] - 1s 43ms/step - loss: 1.9376 - val_loss: 4.8356
# Epoch 23/50
# 34/34 [==============================] - 2s 49ms/step - loss: 1.9384 - val_loss: 4.8388
# Epoch 24/50
# 34/34 [==============================] - 2s 44ms/step - loss: 1.9364 - val_loss: 4.8230
# Epoch 25/50
# 34/34 [==============================] - 1s 38ms/step - loss: 1.9517 - val_loss: 4.8547
# Epoch 26/50
# 34/34 [==============================] - 2s 53ms/step - loss: 1.9534 - val_loss: 4.8731
# Epoch 27/50
# 34/34 [==============================] - 1s 44ms/step - loss: 1.9322 - val_loss: 4.9097
# Epoch 28/50
# 34/34 [==============================] - 2s 53ms/step - loss: 1.9477 - val_loss: 4.7934
# Epoch 29/50
# 34/34 [==============================] - 1s 43ms/step - loss: 1.9500 - val_loss: 4.8382
# Epoch 30/50
# 34/34 [==============================] - 2s 58ms/step - loss: 1.9241 - val_loss: 4.7805
# Epoch 31/50
# 34/34 [==============================] - 5s 136ms/step - loss: 1.9116 - val_loss: 4.7815
# Epoch 32/50
# 34/34 [==============================] - 2s 57ms/step - loss: 1.9222 - val_loss: 4.7661
# Epoch 33/50
# 34/34 [==============================] - 2s 49ms/step - loss: 1.9326 - val_loss: 4.7676
# Epoch 34/50
# 34/34 [==============================] - 3s 83ms/step - loss: 1.9146 - val_loss: 4.7466
# Epoch 35/50
# 34/34 [==============================] - 2s 70ms/step - loss: 1.9051 - val_loss: 4.7595
# Epoch 36/50
# 34/34 [==============================] - 2s 60ms/step - loss: 1.8961 - val_loss: 4.7825
# Epoch 37/50
# 34/34 [==============================] - 2s 54ms/step - loss: 1.9122 - val_loss: 4.7246
# Epoch 38/50
# 34/34 [==============================] - 2s 47ms/step - loss: 1.9175 - val_loss: 4.7221
# Epoch 39/50
# 34/34 [==============================] - 2s 64ms/step - loss: 1.8877 - val_loss: 4.7164
# Epoch 40/50
# 34/34 [==============================] - 2s 57ms/step - loss: 1.8846 - val_loss: 4.7447
# Epoch 41/50
# 34/34 [==============================] - 1s 44ms/step - loss: 1.8863 - val_loss: 4.7970
# Epoch 42/50
# 34/34 [==============================] - 2s 47ms/step - loss: 1.8876 - val_loss: 4.7109
# Epoch 43/50
# 34/34 [==============================] - 2s 61ms/step - loss: 1.8823 - val_loss: 4.7586
# Epoch 44/50
# 34/34 [==============================] - 2s 60ms/step - loss: 1.8811 - val_loss: 4.6588
# Epoch 45/50
# 34/34 [==============================] - 2s 56ms/step - loss: 1.8669 - val_loss: 4.6478
# Epoch 46/50
# 34/34 [==============================] - 1s 43ms/step - loss: 1.8734 - val_loss: 4.6738
# Epoch 47/50
# 34/34 [==============================] - 1s 43ms/step - loss: 1.8705 - val_loss: 4.6660
# Epoch 48/50
# 34/34 [==============================] - 2s 50ms/step - loss: 1.8546 - val_loss: 4.6341
# Epoch 49/50
# 34/34 [==============================] - 3s 88ms/step - loss: 1.9076 - val_loss: 4.7355
# Epoch 50/50
# 34/34 [==============================] - 2s 65ms/step - loss: 1.9036 - val_loss: 4.6019

# %%
# Historia de pérdida en el entrenamiento y la validación
train_loss = history.history['loss']
val_loss = history.history['val_loss']

# Gráfico de pérdida del modelo
plt.plot(train_loss, label='Training Loss', linestyle='--', marker='o')
plt.plot(val_loss, label='Validation Loss', linestyle='--', marker='o')

plt.title('Pérdida de modelo')
plt.xlabel('Epoch')
plt.ylabel('Loss')

plt.legend(loc='upper left')

# Mostrar el gráfico
plt.show()

# %%
train_predict = model.predict(train_X)
test_predict = model.predict(test_X)

print('Shape of train and test predict: ', train_predict.shape, test_predict.shape)
# Out:
# 74/74 [==============================] - 1s 20ms/step
# 19/19 [==============================] - 1s 26ms/step
# Shape of train and test predict:  (2362, 1) (590, 1)

# %%
import math
from sklearn.metrics import mean_squared_error

def calculate_rmse(actual, predicted):
    """
    Calculando el error cuadrático medio (RMSE) entre los valores reales y predichos.

    """
    return math.sqrt(mean_squared_error(actual, predicted))

# Calcular el RMSE para los conjuntos de entrenamiento y prueba
train_rmse = calculate_rmse(train_y, train_predict)
test_rmse = calculate_rmse(test_y, test_predict)

# Imprimir el RMSE
print(f'Train RMSE: {train_rmse:.2f}')
print(f'Test RMSE: {test_rmse:.2f}')
# Out:
# Train RMSE: 1.46
# Test RMSE: 29.37

# %%
plt.figure(figsize=(14, 8))
plt.rcParams.update({'font.size': 9})

# Gráfico de los datos reales y predicciones
plt.plot(test_y, label='Actual', linestyle='--', marker='o')
plt.plot(test_predict, label='Predicted', linestyle='--', marker='o')

plt.xlabel('Tiempo en días')
plt.ylabel('Precio ajustado')
plt.title('Predicción del precio de las acciones de Tesla utilizando RNN simple: datos de prueba')

plt.legend(loc='upper left')

# Mostrar el gráfico
plt.show()
